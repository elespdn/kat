# %% [markdown]
# ## Collation_1
# Collation on the semi-diplomatic transcription. Regularize spelling: 'í' to 'i'.
# Collation is performed with segmentation=False, for easiness of comparison with the following results.

# %%
from collatex import *
collation = Collation()
TO = open( "text/TO1.txt", encoding='utf-8' ).read()
RI = open( "text/RI1.txt", encoding='utf-8' ).read()
CH = open( "text/CH1.txt", encoding='utf-8' ).read()
collation.add_plain_witness( "TO", TO )
collation.add_plain_witness( "RI", RI )
collation.add_plain_witness( "CH", CH )
table = collate(collation, output='html2', segmentation=False)
print(table)
# Out:
# <TABLE border="1" cellpadding="4" style="border: 1px solid #000000; border-collapse: collapse;">
#  <TR>
#   <TH>TO</TH>
#   <TH>RI</TH>
#   <TH>CH</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">NEl</TD>
#   <TD bgcolor="#FACC2E">NEl</TD>
#   <TD bgcolor="#FACC2E">NEl</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">meçço</TD>
#   <TD bgcolor="#2ECCFA">meçço</TD>
#   <TD bgcolor="#2ECCFA">meço</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">del</TD>
#   <TD bgcolor="#FACC2E">del</TD>
#   <TD bgcolor="#FACC2E">del</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">cammin</TD>
#   <TD bgcolor="#2ECCFA">camin</TD>
#   <TD bgcolor="#2ECCFA">cammin</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">di</TD>
#   <TD bgcolor="#FACC2E">di</TD>
#   <TD bgcolor="#FACC2E">di</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">nostra</TD>
#   <TD bgcolor="#FACC2E">nostra</TD>
#   <TD bgcolor="#FACC2E">nostra</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">vita</TD>
#   <TD bgcolor="#FACC2E">vita</TD>
#   <TD bgcolor="#FACC2E">vita</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">mi</TD>
#   <TD bgcolor="#FACC2E">mi</TD>
#   <TD bgcolor="#FACC2E">mi</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">ritrovai</TD>
#   <TD bgcolor="#FACC2E">ritrovai</TD>
#   <TD bgcolor="#FACC2E">ritrovai</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">per</TD>
#   <TD bgcolor="#FACC2E">per</TD>
#   <TD bgcolor="#FACC2E">per</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">una</TD>
#   <TD bgcolor="#FACC2E">una</TD>
#   <TD bgcolor="#FACC2E">una</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">selva</TD>
#   <TD bgcolor="#FACC2E">selva</TD>
#   <TD bgcolor="#FACC2E">selva</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">obscura</TD>
#   <TD bgcolor="#FACC2E">obscura</TD>
#   <TD bgcolor="#FACC2E">obscura</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">che</TD>
#   <TD bgcolor="#FACC2E">che</TD>
#   <TD bgcolor="#FACC2E">che</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">la</TD>
#   <TD bgcolor="#FACC2E">la</TD>
#   <TD bgcolor="#FACC2E">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">diricta</TD>
#   <TD bgcolor="#FACC2E">diricta</TD>
#   <TD bgcolor="#FACC2E">diricta</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">via</TD>
#   <TD bgcolor="#FACC2E">via</TD>
#   <TD bgcolor="#FACC2E">via</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">era</TD>
#   <TD bgcolor="#FACC2E">era</TD>
#   <TD bgcolor="#FACC2E">era</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">smarrita</TD>
#   <TD bgcolor="#FACC2E">smarrita</TD>
#   <TD bgcolor="#FACC2E">smarrita</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">Et</TD>
#   <TD bgcolor="#FACC2E">Et</TD>
#   <TD bgcolor="#FACC2E">Et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">quanto</TD>
#   <TD bgcolor="#FACC2E">quanto</TD>
#   <TD bgcolor="#FACC2E">quanto</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">ad</TD>
#   <TD bgcolor="#2ECCFA">a</TD>
#   <TD bgcolor="#2ECCFA">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">dir</TD>
#   <TD bgcolor="#2ECCFA">dir</TD>
#   <TD bgcolor="#2ECCFA">ddir</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">quale</TD>
#   <TD bgcolor="#2ECCFA">qual</TD>
#   <TD bgcolor="#2ECCFA">qual</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">-</TD>
#   <TD bgcolor="#2ECCFA">'</TD>
#   <TD bgcolor="#2ECCFA">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">era</TD>
#   <TD bgcolor="#FACC2E">era</TD>
#   <TD bgcolor="#FACC2E">era</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">e</TD>
#   <TD bgcolor="#FACC2E">e</TD>
#   <TD bgcolor="#FACC2E">e</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">cosa</TD>
#   <TD bgcolor="#FACC2E">cosa</TD>
#   <TD bgcolor="#FACC2E">cosa</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">dura</TD>
#   <TD bgcolor="#FACC2E">dura</TD>
#   <TD bgcolor="#FACC2E">dura</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">esta</TD>
#   <TD bgcolor="#FACC2E">esta</TD>
#   <TD bgcolor="#FACC2E">esta</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">selva</TD>
#   <TD bgcolor="#FACC2E">selva</TD>
#   <TD bgcolor="#FACC2E">selva</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">selvaggia</TD>
#   <TD bgcolor="#FACC2E">selvaggia</TD>
#   <TD bgcolor="#FACC2E">selvaggia</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">et</TD>
#   <TD bgcolor="#FACC2E">et</TD>
#   <TD bgcolor="#FACC2E">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">aspra</TD>
#   <TD bgcolor="#FACC2E">aspra</TD>
#   <TD bgcolor="#FACC2E">aspra</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">et</TD>
#   <TD bgcolor="#FACC2E">et</TD>
#   <TD bgcolor="#FACC2E">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">forte</TD>
#   <TD bgcolor="#FACC2E">forte</TD>
#   <TD bgcolor="#FACC2E">forte</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">che</TD>
#   <TD bgcolor="#FACC2E">che</TD>
#   <TD bgcolor="#FACC2E">che</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">nel</TD>
#   <TD bgcolor="#FACC2E">nel</TD>
#   <TD bgcolor="#FACC2E">nel</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">pensier</TD>
#   <TD bgcolor="#FACC2E">pensier</TD>
#   <TD bgcolor="#FACC2E">pensier</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">rinnova</TD>
#   <TD bgcolor="#2ECCFA">rinnova</TD>
#   <TD bgcolor="#2ECCFA">rinnuova</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">la</TD>
#   <TD bgcolor="#FACC2E">la</TD>
#   <TD bgcolor="#FACC2E">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">paura</TD>
#   <TD bgcolor="#FACC2E">paura</TD>
#   <TD bgcolor="#FACC2E">paura</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">Tanto</TD>
#   <TD bgcolor="#2ECCFA">Tant</TD>
#   <TD bgcolor="#2ECCFA">Tanto</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">-</TD>
#   <TD bgcolor="#2ECCFA">'</TD>
#   <TD bgcolor="#2ECCFA">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">e</TD>
#   <TD bgcolor="#FACC2E">e</TD>
#   <TD bgcolor="#FACC2E">e</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">amara</TD>
#   <TD bgcolor="#FACC2E">amara</TD>
#   <TD bgcolor="#FACC2E">amara</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">che</TD>
#   <TD bgcolor="#FACC2E">che</TD>
#   <TD bgcolor="#FACC2E">che</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">poco</TD>
#   <TD bgcolor="#FACC2E">poco</TD>
#   <TD bgcolor="#FACC2E">poco</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">e</TD>
#   <TD bgcolor="#FACC2E">e</TD>
#   <TD bgcolor="#FACC2E">e</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">piu</TD>
#   <TD bgcolor="#FACC2E">piu</TD>
#   <TD bgcolor="#FACC2E">piu</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">morte</TD>
#   <TD bgcolor="#FACC2E">morte</TD>
#   <TD bgcolor="#FACC2E">morte</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">ma</TD>
#   <TD bgcolor="#FACC2E">ma</TD>
#   <TD bgcolor="#FACC2E">ma</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">per</TD>
#   <TD bgcolor="#FACC2E">per</TD>
#   <TD bgcolor="#FACC2E">per</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">tractar</TD>
#   <TD bgcolor="#FACC2E">tractar</TD>
#   <TD bgcolor="#FACC2E">tractar</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">del</TD>
#   <TD bgcolor="#FACC2E">del</TD>
#   <TD bgcolor="#FACC2E">del</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">ben</TD>
#   <TD bgcolor="#FACC2E">ben</TD>
#   <TD bgcolor="#FACC2E">ben</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">ch</TD>
#   <TD bgcolor="#FACC2E">ch</TD>
#   <TD bgcolor="#FACC2E">ch</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">'</TD>
#   <TD bgcolor="#FACC2E">'</TD>
#   <TD bgcolor="#FACC2E">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">io</TD>
#   <TD bgcolor="#FACC2E">io</TD>
#   <TD bgcolor="#FACC2E">io</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">vi</TD>
#   <TD bgcolor="#FACC2E">vi</TD>
#   <TD bgcolor="#FACC2E">vi</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">trovai</TD>
#   <TD bgcolor="#FACC2E">trovai</TD>
#   <TD bgcolor="#FACC2E">trovai</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">diro</TD>
#   <TD bgcolor="#FACC2E">diro</TD>
#   <TD bgcolor="#FACC2E">diro</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">dell</TD>
#   <TD bgcolor="#FACC2E">dell</TD>
#   <TD bgcolor="#FACC2E">dell</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">'</TD>
#   <TD bgcolor="#FACC2E">'</TD>
#   <TD bgcolor="#FACC2E">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">altre</TD>
#   <TD bgcolor="#FACC2E">altre</TD>
#   <TD bgcolor="#FACC2E">altre</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">cose</TD>
#   <TD bgcolor="#FACC2E">cose</TD>
#   <TD bgcolor="#FACC2E">cose</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">ch</TD>
#   <TD bgcolor="#FACC2E">ch</TD>
#   <TD bgcolor="#FACC2E">ch</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">'</TD>
#   <TD bgcolor="#FACC2E">'</TD>
#   <TD bgcolor="#FACC2E">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">io</TD>
#   <TD bgcolor="#FACC2E">io</TD>
#   <TD bgcolor="#FACC
# None

# %% [markdown]
# ## Collation_2
# Same as Collation_1, adding parameter: near_match=True.

# %%
from collatex import *
collation = Collation()
TO = open( "text/TO1.txt", encoding='utf-8' ).read()
RI = open( "text/RI1.txt", encoding='utf-8' ).read()
CH = open( "text/CH1.txt", encoding='utf-8' ).read()
collation.add_plain_witness( "TO", TO )
collation.add_plain_witness( "RI", RI )
collation.add_plain_witness( "CH", CH )
table = collate(collation, output='html2', near_match=True, segmentation=False)
print(table)
# Out:
# <TABLE border="1" cellpadding="4" style="border: 1px solid #000000; border-collapse: collapse;">
#  <TR>
#   <TH>TO</TH>
#   <TH>RI</TH>
#   <TH>CH</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">NEl</TD>
#   <TD bgcolor="#FACC2E">NEl</TD>
#   <TD bgcolor="#FACC2E">NEl</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">meçço</TD>
#   <TD bgcolor="#2ECCFA">meçço</TD>
#   <TD bgcolor="#2ECCFA">meço</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">del</TD>
#   <TD bgcolor="#FACC2E">del</TD>
#   <TD bgcolor="#FACC2E">del</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">cammin</TD>
#   <TD bgcolor="#2ECCFA">camin</TD>
#   <TD bgcolor="#2ECCFA">cammin</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">di</TD>
#   <TD bgcolor="#FACC2E">di</TD>
#   <TD bgcolor="#FACC2E">di</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">nostra</TD>
#   <TD bgcolor="#FACC2E">nostra</TD>
#   <TD bgcolor="#FACC2E">nostra</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">vita</TD>
#   <TD bgcolor="#FACC2E">vita</TD>
#   <TD bgcolor="#FACC2E">vita</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">mi</TD>
#   <TD bgcolor="#FACC2E">mi</TD>
#   <TD bgcolor="#FACC2E">mi</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">ritrovai</TD>
#   <TD bgcolor="#FACC2E">ritrovai</TD>
#   <TD bgcolor="#FACC2E">ritrovai</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">per</TD>
#   <TD bgcolor="#FACC2E">per</TD>
#   <TD bgcolor="#FACC2E">per</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">una</TD>
#   <TD bgcolor="#FACC2E">una</TD>
#   <TD bgcolor="#FACC2E">una</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">selva</TD>
#   <TD bgcolor="#FACC2E">selva</TD>
#   <TD bgcolor="#FACC2E">selva</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">obscura</TD>
#   <TD bgcolor="#FACC2E">obscura</TD>
#   <TD bgcolor="#FACC2E">obscura</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">che</TD>
#   <TD bgcolor="#FACC2E">che</TD>
#   <TD bgcolor="#FACC2E">che</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">la</TD>
#   <TD bgcolor="#FACC2E">la</TD>
#   <TD bgcolor="#FACC2E">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">diricta</TD>
#   <TD bgcolor="#FACC2E">diricta</TD>
#   <TD bgcolor="#FACC2E">diricta</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">via</TD>
#   <TD bgcolor="#FACC2E">via</TD>
#   <TD bgcolor="#FACC2E">via</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">era</TD>
#   <TD bgcolor="#FACC2E">era</TD>
#   <TD bgcolor="#FACC2E">era</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">smarrita</TD>
#   <TD bgcolor="#FACC2E">smarrita</TD>
#   <TD bgcolor="#FACC2E">smarrita</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">Et</TD>
#   <TD bgcolor="#FACC2E">Et</TD>
#   <TD bgcolor="#FACC2E">Et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">quanto</TD>
#   <TD bgcolor="#FACC2E">quanto</TD>
#   <TD bgcolor="#FACC2E">quanto</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">ad</TD>
#   <TD bgcolor="#2ECCFA">a</TD>
#   <TD bgcolor="#2ECCFA">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">dir</TD>
#   <TD bgcolor="#2ECCFA">dir</TD>
#   <TD bgcolor="#2ECCFA">ddir</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">quale</TD>
#   <TD bgcolor="#2ECCFA">qual</TD>
#   <TD bgcolor="#2ECCFA">qual</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">-</TD>
#   <TD bgcolor="#2ECCFA">'</TD>
#   <TD bgcolor="#2ECCFA">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">era</TD>
#   <TD bgcolor="#FACC2E">era</TD>
#   <TD bgcolor="#FACC2E">era</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">e</TD>
#   <TD bgcolor="#FACC2E">e</TD>
#   <TD bgcolor="#FACC2E">e</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">cosa</TD>
#   <TD bgcolor="#FACC2E">cosa</TD>
#   <TD bgcolor="#FACC2E">cosa</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">dura</TD>
#   <TD bgcolor="#FACC2E">dura</TD>
#   <TD bgcolor="#FACC2E">dura</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">esta</TD>
#   <TD bgcolor="#FACC2E">esta</TD>
#   <TD bgcolor="#FACC2E">esta</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">selva</TD>
#   <TD bgcolor="#FACC2E">selva</TD>
#   <TD bgcolor="#FACC2E">selva</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">selvaggia</TD>
#   <TD bgcolor="#FACC2E">selvaggia</TD>
#   <TD bgcolor="#FACC2E">selvaggia</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">et</TD>
#   <TD bgcolor="#FACC2E">et</TD>
#   <TD bgcolor="#FACC2E">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">aspra</TD>
#   <TD bgcolor="#FACC2E">aspra</TD>
#   <TD bgcolor="#FACC2E">aspra</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">et</TD>
#   <TD bgcolor="#FACC2E">et</TD>
#   <TD bgcolor="#FACC2E">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">forte</TD>
#   <TD bgcolor="#FACC2E">forte</TD>
#   <TD bgcolor="#FACC2E">forte</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">che</TD>
#   <TD bgcolor="#FACC2E">che</TD>
#   <TD bgcolor="#FACC2E">che</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">nel</TD>
#   <TD bgcolor="#FACC2E">nel</TD>
#   <TD bgcolor="#FACC2E">nel</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">pensier</TD>
#   <TD bgcolor="#FACC2E">pensier</TD>
#   <TD bgcolor="#FACC2E">pensier</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">rinnova</TD>
#   <TD bgcolor="#2ECCFA">rinnova</TD>
#   <TD bgcolor="#2ECCFA">rinnuova</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">la</TD>
#   <TD bgcolor="#FACC2E">la</TD>
#   <TD bgcolor="#FACC2E">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">paura</TD>
#   <TD bgcolor="#FACC2E">paura</TD>
#   <TD bgcolor="#FACC2E">paura</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">Tanto</TD>
#   <TD bgcolor="#2ECCFA">Tant</TD>
#   <TD bgcolor="#2ECCFA">Tanto</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">-</TD>
#   <TD bgcolor="#2ECCFA">'</TD>
#   <TD bgcolor="#2ECCFA">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">e</TD>
#   <TD bgcolor="#FACC2E">e</TD>
#   <TD bgcolor="#FACC2E">e</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">amara</TD>
#   <TD bgcolor="#FACC2E">amara</TD>
#   <TD bgcolor="#FACC2E">amara</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">che</TD>
#   <TD bgcolor="#FACC2E">che</TD>
#   <TD bgcolor="#FACC2E">che</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">poco</TD>
#   <TD bgcolor="#FACC2E">poco</TD>
#   <TD bgcolor="#FACC2E">poco</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">e</TD>
#   <TD bgcolor="#FACC2E">e</TD>
#   <TD bgcolor="#FACC2E">e</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">piu</TD>
#   <TD bgcolor="#FACC2E">piu</TD>
#   <TD bgcolor="#FACC2E">piu</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">morte</TD>
#   <TD bgcolor="#FACC2E">morte</TD>
#   <TD bgcolor="#FACC2E">morte</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">ma</TD>
#   <TD bgcolor="#FACC2E">ma</TD>
#   <TD bgcolor="#FACC2E">ma</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">per</TD>
#   <TD bgcolor="#FACC2E">per</TD>
#   <TD bgcolor="#FACC2E">per</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">tractar</TD>
#   <TD bgcolor="#FACC2E">tractar</TD>
#   <TD bgcolor="#FACC2E">tractar</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">del</TD>
#   <TD bgcolor="#FACC2E">del</TD>
#   <TD bgcolor="#FACC2E">del</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">ben</TD>
#   <TD bgcolor="#FACC2E">ben</TD>
#   <TD bgcolor="#FACC2E">ben</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">ch</TD>
#   <TD bgcolor="#FACC2E">ch</TD>
#   <TD bgcolor="#FACC2E">ch</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">'</TD>
#   <TD bgcolor="#FACC2E">'</TD>
#   <TD bgcolor="#FACC2E">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">io</TD>
#   <TD bgcolor="#FACC2E">io</TD>
#   <TD bgcolor="#FACC2E">io</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">vi</TD>
#   <TD bgcolor="#FACC2E">vi</TD>
#   <TD bgcolor="#FACC2E">vi</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">trovai</TD>
#   <TD bgcolor="#FACC2E">trovai</TD>
#   <TD bgcolor="#FACC2E">trovai</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">diro</TD>
#   <TD bgcolor="#FACC2E">diro</TD>
#   <TD bgcolor="#FACC2E">diro</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">dell</TD>
#   <TD bgcolor="#FACC2E">dell</TD>
#   <TD bgcolor="#FACC2E">dell</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">'</TD>
#   <TD bgcolor="#FACC2E">'</TD>
#   <TD bgcolor="#FACC2E">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">altre</TD>
#   <TD bgcolor="#FACC2E">altre</TD>
#   <TD bgcolor="#FACC2E">altre</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">cose</TD>
#   <TD bgcolor="#FACC2E">cose</TD>
#   <TD bgcolor="#FACC2E">cose</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">ch</TD>
#   <TD bgcolor="#FACC2E">ch</TD>
#   <TD bgcolor="#FACC2E">ch</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">'</TD>
#   <TD bgcolor="#FACC2E">'</TD>
#   <TD bgcolor="#FACC2E">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">io</TD>
#   <TD bgcolor="#FACC2E">io</TD>
#   <TD bgcolor="#FACC
# None

# %% [markdown]
# ## Collation_3: TABLE
# Spelling is normalized using forms in dictionary.csv, created manually, and collation performed on normalized forms.
# <br/>The output is rendered both in a table and as a graph (below).

# %%
import csv
import re

#create the dictionary (here: Dictionary.csv consisting in two columns, separated by a comma. The first Column 'Original' are the strings as found in the text, the second column 'Normalised' contains the strings you want to replace them with. No whitespaces behind the strings.) 
Normit = {}
with open('dictionary.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'],  dialect='excel')
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()
#testimone_P4 = open( "lettere/T196-part1-clean-P4.txt", encoding='utf-8' ).read()
#testimone_S2 = open( "lettere/T196-part1-clean-S2.txt", encoding='utf-8' ).read()
#testimone_S4 = open( "lettere/T196-part1-clean-S4.txt", encoding='utf-8' ).read()

# build a function to tokenize and to normalize by replace keys to be found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_TO = tokennormalizer(TO) 
tokens_RI = tokennormalizer(RI) 
tokens_CH = tokennormalizer(CH) 


witness_TO = { "id": "TO", "tokens":tokens_TO }
witness_RI = { "id": "RI", "tokens":tokens_RI }
witness_CH = { "id": "CH", "tokens":tokens_CH }


input = { "witnesses": [ witness_TO, witness_RI, witness_CH ] }

table = collate(input, output='html2', segmentation=False)
# Out:
# <TABLE border="1" cellpadding="4" style="border: 1px solid #000000; border-collapse: collapse;">
#  <TR>
#   <TH>TO</TH>
#   <TH>RI</TH>
#   <TH>CH</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">NEl</TD>
#   <TD bgcolor="#FACC2E">NEl</TD>
#   <TD bgcolor="#FACC2E">NEl</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">meçço</TD>
#   <TD bgcolor="#FACC2E">meçço</TD>
#   <TD bgcolor="#FACC2E">meço</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">del</TD>
#   <TD bgcolor="#FACC2E">del</TD>
#   <TD bgcolor="#FACC2E">del</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">cammin</TD>
#   <TD bgcolor="#FACC2E">camin</TD>
#   <TD bgcolor="#FACC2E">cammin</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">di</TD>
#   <TD bgcolor="#FACC2E">di</TD>
#   <TD bgcolor="#FACC2E">di</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">nostra</TD>
#   <TD bgcolor="#FACC2E">nostra</TD>
#   <TD bgcolor="#FACC2E">nostra</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">vita</TD>
#   <TD bgcolor="#FACC2E">vita</TD>
#   <TD bgcolor="#FACC2E">vita</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">mi</TD>
#   <TD bgcolor="#FACC2E">mi</TD>
#   <TD bgcolor="#FACC2E">mi</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">ritrovai</TD>
#   <TD bgcolor="#FACC2E">ritrovai</TD>
#   <TD bgcolor="#FACC2E">ritrovai</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">per</TD>
#   <TD bgcolor="#FACC2E">per</TD>
#   <TD bgcolor="#FACC2E">per</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">una</TD>
#   <TD bgcolor="#FACC2E">una</TD>
#   <TD bgcolor="#FACC2E">una</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">selva</TD>
#   <TD bgcolor="#FACC2E">selva</TD>
#   <TD bgcolor="#FACC2E">selva</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">obscura</TD>
#   <TD bgcolor="#FACC2E">obscura</TD>
#   <TD bgcolor="#FACC2E">obscura</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">che</TD>
#   <TD bgcolor="#FACC2E">che</TD>
#   <TD bgcolor="#FACC2E">che</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">la</TD>
#   <TD bgcolor="#FACC2E">la</TD>
#   <TD bgcolor="#FACC2E">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">diricta</TD>
#   <TD bgcolor="#FACC2E">diricta</TD>
#   <TD bgcolor="#FACC2E">diricta</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">via</TD>
#   <TD bgcolor="#FACC2E">via</TD>
#   <TD bgcolor="#FACC2E">via</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">era</TD>
#   <TD bgcolor="#FACC2E">era</TD>
#   <TD bgcolor="#FACC2E">era</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">smarrita</TD>
#   <TD bgcolor="#FACC2E">smarrita</TD>
#   <TD bgcolor="#FACC2E">smarrita</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">Et</TD>
#   <TD bgcolor="#FACC2E">Et</TD>
#   <TD bgcolor="#FACC2E">Et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">quanto</TD>
#   <TD bgcolor="#FACC2E">quanto</TD>
#   <TD bgcolor="#FACC2E">quanto</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">ad</TD>
#   <TD bgcolor="#2ECCFA">a</TD>
#   <TD bgcolor="#2ECCFA">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">dir</TD>
#   <TD bgcolor="#2ECCFA">dir</TD>
#   <TD bgcolor="#2ECCFA">ddir</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">quale</TD>
#   <TD bgcolor="#2ECCFA">qual</TD>
#   <TD bgcolor="#2ECCFA">qual</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">-</TD>
#   <TD bgcolor="#2ECCFA">'</TD>
#   <TD bgcolor="#2ECCFA">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">era</TD>
#   <TD bgcolor="#FACC2E">era</TD>
#   <TD bgcolor="#FACC2E">era</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">e</TD>
#   <TD bgcolor="#FACC2E">e</TD>
#   <TD bgcolor="#FACC2E">e</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">cosa</TD>
#   <TD bgcolor="#FACC2E">cosa</TD>
#   <TD bgcolor="#FACC2E">cosa</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">dura</TD>
#   <TD bgcolor="#FACC2E">dura</TD>
#   <TD bgcolor="#FACC2E">dura</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">esta</TD>
#   <TD bgcolor="#FACC2E">esta</TD>
#   <TD bgcolor="#FACC2E">esta</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">selva</TD>
#   <TD bgcolor="#FACC2E">selva</TD>
#   <TD bgcolor="#FACC2E">selva</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">selvaggia</TD>
#   <TD bgcolor="#FACC2E">selvaggia</TD>
#   <TD bgcolor="#FACC2E">selvaggia</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">et</TD>
#   <TD bgcolor="#FACC2E">et</TD>
#   <TD bgcolor="#FACC2E">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">aspra</TD>
#   <TD bgcolor="#FACC2E">aspra</TD>
#   <TD bgcolor="#FACC2E">aspra</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">et</TD>
#   <TD bgcolor="#FACC2E">et</TD>
#   <TD bgcolor="#FACC2E">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">forte</TD>
#   <TD bgcolor="#FACC2E">forte</TD>
#   <TD bgcolor="#FACC2E">forte</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">che</TD>
#   <TD bgcolor="#FACC2E">che</TD>
#   <TD bgcolor="#FACC2E">che</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">nel</TD>
#   <TD bgcolor="#FACC2E">nel</TD>
#   <TD bgcolor="#FACC2E">nel</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">pensier</TD>
#   <TD bgcolor="#FACC2E">pensier</TD>
#   <TD bgcolor="#FACC2E">pensier</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">rinnova</TD>
#   <TD bgcolor="#FACC2E">rinnova</TD>
#   <TD bgcolor="#FACC2E">rinnuova</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">la</TD>
#   <TD bgcolor="#FACC2E">la</TD>
#   <TD bgcolor="#FACC2E">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">paura</TD>
#   <TD bgcolor="#FACC2E">paura</TD>
#   <TD bgcolor="#FACC2E">paura</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">Tanto</TD>
#   <TD bgcolor="#2ECCFA">Tant</TD>
#   <TD bgcolor="#2ECCFA">Tanto</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#2ECCFA">-</TD>
#   <TD bgcolor="#2ECCFA">'</TD>
#   <TD bgcolor="#2ECCFA">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">e</TD>
#   <TD bgcolor="#FACC2E">e</TD>
#   <TD bgcolor="#FACC2E">e</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">amara</TD>
#   <TD bgcolor="#FACC2E">amara</TD>
#   <TD bgcolor="#FACC2E">amara</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">che</TD>
#   <TD bgcolor="#FACC2E">che</TD>
#   <TD bgcolor="#FACC2E">che</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">poco</TD>
#   <TD bgcolor="#FACC2E">poco</TD>
#   <TD bgcolor="#FACC2E">poco</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">e</TD>
#   <TD bgcolor="#FACC2E">e</TD>
#   <TD bgcolor="#FACC2E">e</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">piu</TD>
#   <TD bgcolor="#FACC2E">piu</TD>
#   <TD bgcolor="#FACC2E">piu</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">morte</TD>
#   <TD bgcolor="#FACC2E">morte</TD>
#   <TD bgcolor="#FACC2E">morte</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">ma</TD>
#   <TD bgcolor="#FACC2E">ma</TD>
#   <TD bgcolor="#FACC2E">ma</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">per</TD>
#   <TD bgcolor="#FACC2E">per</TD>
#   <TD bgcolor="#FACC2E">per</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">tractar</TD>
#   <TD bgcolor="#FACC2E">tractar</TD>
#   <TD bgcolor="#FACC2E">tractar</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">del</TD>
#   <TD bgcolor="#FACC2E">del</TD>
#   <TD bgcolor="#FACC2E">del</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">ben</TD>
#   <TD bgcolor="#FACC2E">ben</TD>
#   <TD bgcolor="#FACC2E">ben</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">ch</TD>
#   <TD bgcolor="#FACC2E">ch</TD>
#   <TD bgcolor="#FACC2E">ch</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">'</TD>
#   <TD bgcolor="#FACC2E">'</TD>
#   <TD bgcolor="#FACC2E">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">io</TD>
#   <TD bgcolor="#FACC2E">io</TD>
#   <TD bgcolor="#FACC2E">io</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">vi</TD>
#   <TD bgcolor="#FACC2E">vi</TD>
#   <TD bgcolor="#FACC2E">vi</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">trovai</TD>
#   <TD bgcolor="#FACC2E">trovai</TD>
#   <TD bgcolor="#FACC2E">trovai</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">diro</TD>
#   <TD bgcolor="#FACC2E">diro</TD>
#   <TD bgcolor="#FACC2E">diro</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">dell</TD>
#   <TD bgcolor="#FACC2E">dell</TD>
#   <TD bgcolor="#FACC2E">dell</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">'</TD>
#   <TD bgcolor="#FACC2E">'</TD>
#   <TD bgcolor="#FACC2E">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">altre</TD>
#   <TD bgcolor="#FACC2E">altre</TD>
#   <TD bgcolor="#FACC2E">altre</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">cose</TD>
#   <TD bgcolor="#FACC2E">cose</TD>
#   <TD bgcolor="#FACC2E">cose</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">ch</TD>
#   <TD bgcolor="#FACC2E">ch</TD>
#   <TD bgcolor="#FACC2E">ch</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">'</TD>
#   <TD bgcolor="#FACC2E">'</TD>
#   <TD bgcolor="#FACC2E">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#FACC2E">io</TD>
#   <TD bgcolor="#FACC2E">io</TD>
#   <TD bgcolor="#FACC

# %% [markdown]
# ## Collation_3: GRAPH

# %%
import csv
import re

#create the dictionary (here: Dictionary.csv consisting in two columns, separated by a comma. The first Column 'Original' are the strings as found in the text, the second column 'Normalised' contains the strings you want to replace them with. No whitespaces behind the strings.) 
Normit = {}
with open('dictionary.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'],  dialect='excel')
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()
#testimone_P4 = open( "lettere/T196-part1-clean-P4.txt", encoding='utf-8' ).read()
#testimone_S2 = open( "lettere/T196-part1-clean-S2.txt", encoding='utf-8' ).read()
#testimone_S4 = open( "lettere/T196-part1-clean-S4.txt", encoding='utf-8' ).read()

# build a function to tokenize and to normalize by replace keys to be found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_TO = tokennormalizer(TO) 
tokens_RI = tokennormalizer(RI) 
tokens_CH = tokennormalizer(CH) 


witness_TO = { "id": "TO", "tokens":tokens_TO }
witness_RI = { "id": "RI", "tokens":tokens_RI }
witness_CH = { "id": "CH", "tokens":tokens_CH }


input = { "witnesses": [ witness_TO, witness_RI, witness_CH ] }

graph = collate(input, output='svg', segmentation=False)
print(graph)
# Out:
# None

# %% [markdown]
# ## Collation_4
# A normalized form is created using the lemma + POS (part of speech). Those information are generated automatically using NLP software Treetagger. In particular, for the analysis of Dante's language (and more in general 13th century Italian), we used D(h)ante, from Angelo Basile (Fondazione Bruno Kessler), available at <http://dh.fbk.eu/D%28h%29ante>.

# %%
import csv
import re

#create the dictionary (here: Dictionary.csv consisting in two columns, separated by a comma. The first Column 'Original' are the strings as found in the text, the second column 'Normalised' contains the strings you want to replace them with. No whitespaces behind the strings.) 
Normit = {}
with open('lemma.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'],  dialect='excel')
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()
#testimone_P4 = open( "lettere/T196-part1-clean-P4.txt", encoding='utf-8' ).read()
#testimone_S2 = open( "lettere/T196-part1-clean-S2.txt", encoding='utf-8' ).read()
#testimone_S4 = open( "lettere/T196-part1-clean-S4.txt", encoding='utf-8' ).read()

# build a function to tokenize and to normalize by replace keys to be found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_TO = tokennormalizer(TO) 
tokens_RI = tokennormalizer(RI) 
tokens_CH = tokennormalizer(CH) 


witness_TO = { "id": "TO", "tokens":tokens_TO }
witness_RI = { "id": "RI", "tokens":tokens_RI }
witness_CH = { "id": "CH", "tokens":tokens_CH }


input = { "witnesses": [ witness_TO, witness_RI, witness_CH ] }

graph = collate(input, output='svg', segmentation=False)
print(graph)
# Out:
# None
